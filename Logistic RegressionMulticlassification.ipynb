# %%
import pandas as pd
# Out:
# C:\Users\princ\AppData\Local\Temp\ipykernel_18724\217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset = pd.read_csv('Iris.csv')
print(dataset)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset['Species'].replace({"Iris-setosa": "1","Iris-versicolor":"2","Iris-virginica":"3"},inplace=True)
# Out:
# C:\Users\princ\AppData\Local\Temp\ipykernel_18724\802932984.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Species'].replace({"Iris-setosa": "1","Iris-versicolor":"2","Iris-virginica":"3"},inplace=True)

# %%
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1            5.1           3.5            1.4           0.2       1
# 1      2            4.9           3.0            1.4           0.2       1
# 2      3            4.7           3.2            1.3           0.2       1
# 3      4            4.6           3.1            1.5           0.2       1
# 4      5            5.0           3.6            1.4           0.2       1
# ..   ...            ...           ...            ...           ...     ...
# 145  146            6.7           3.0            5.2           2.3       3
# 146  147            6.3           2.5            5.0           1.9       3
# 147  148            6.5           3.0            5.2           2.0       3
# 148  149            6.2           3.4            5.4           2.3       3
# 149  150            5.9           3.0            5.1           1.8       3
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(dataset[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],dataset['Species'],test_size = 0.2)

# %%
print(len(x_train))
# Out:
# 120

# %%
print(len(x_test))
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test,)
# Out:
# array(['1', '3', '1', '1', '2', '2', '1', '3', '2', '2', '2', '3', '1',
#        '3', '1', '3', '3', '2', '2', '2', '2', '1', '1', '2', '2', '2',
#        '1', '2', '3', '3'], dtype=object)

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 23             5.1           3.3            1.7           0.5
# 149            5.9           3.0            5.1           1.8
# 17             5.1           3.5            1.4           0.3
# 33             5.5           4.2            1.4           0.2
# 63             6.1           2.9            4.7           1.4
# 51             6.4           3.2            4.5           1.5
# 5              5.4           3.9            1.7           0.4
# 114            5.8           2.8            5.1           2.4
# 84             5.4           3.0            4.5           1.5
# 86             6.7           3.1            4.7           1.5
# 96             5.7           2.9            4.2           1.3
# 144            6.7           3.3            5.7           2.5
# 7              5.0           3.4            1.5           0.2
# 131            7.9           3.8            6.4           2.0
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 1.0

# %%
import seaborn as sns
# This code snippet is using the Seaborn library to create a pairplot of the specified columns ('SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm') from the dataset. The `hue='Species'` parameter is used to color the data points based on the 'Species' column, allowing you to visualize the relationships between the numerical features while also differentiating the data points by species.
sns.pairplot(dataset[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Species']],hue='Species')
